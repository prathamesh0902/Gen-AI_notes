-- %% [markdown]
-- ## Requirements for Building Deep Learning Models

-- %%
Input neurons = # features     :: IQ, CGPA = 2 neurons
Output neurons
regression / binary classification  >  1 neuron
multi class classfication   =  # categories

Hidden layers > depends on model choice

-- %% [markdown]
-- **GPT as example of Multiclass classification**

-- %%
Llama 70B parameter model
3 input neurons - HL1 (4) - HL() ...  - output()
weights , biases X number of neurons gives total number of parameters
5 x 7 + 7 + (7 x 7 + 7) x 4 + 7 * 4 = 

Diffusion model  :: stable diffusion for generation images
CNN + Multi layered perceptron (MLP)

Transformer =   MLP + Attention

-- %% [markdown]
-- ## Loss Function

-- %%
in image generation, speech data, how to reduce loss function
Loss function tells model how wrong its prediction is
converts difference into a number actual vs predicted
if there is a difference, we will backpropogate


Loss function -  calculate for single training point
cost function - calculate for the whole batch

-- %%
Regression Loss  -  Mean Squared Error
Predict   House price, temperature, salary prediction
MSE loss penalizes larger losses more due to squaring

use MAE in case of Outliers

Classification - Next word prediction task
in image generation, speech data, cat vs dog prediction what loss fn to use?

-- %%
Binary cross entropy - log loss value
activation function in output layer is sigmoid

-- %%
import kagglehub
path = kagglehub.dataset_download("user/dataset-name")
print("Path to dataset files:", path)
