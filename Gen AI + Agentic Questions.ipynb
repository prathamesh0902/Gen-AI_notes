-- %%
%sql
## Q1. Which of the following is correct?

A: df[df['A'] > 2 and df['B']<5]
B: df[(df['A'] > 2) & (df['B']<5)]
C: df[df['A'] > 2 & df['B']<5]
D: df.filter[df['A'] > 2, df['B']<5]

**Answer:** ✅ **B. Why parentheses are needed**
& has higher precedence than comparison operators, so without parentheses,
df['A'] > 2 & df['B'] < 5 will be interpreted incorrectly and may throw an error.


---

## Q2. Hybrid Search Fusion Strategy

**Question:**
You are implementing hybrid search, combining vector similarity search and keyword search. Which fusion strategy is most likely to remain stable across different query types?

A. Fixed weighted linear combination of scores from both retrieval methods
B. Dynamically selecting either vector or keyword search based on query length
C. Reciprocal Rank Fusion (RRF), combining rankings rather than raw scores
D. Using keyword search as a post-filter after vector retrieval

**Answer:** ✅ **C. Reciprocal Rank Fusion (RRF)**

**Explanation:** RRF is robust because it combines rankings instead of incompatible scoring scales.

---

## Q3. Chunk Size Selection

**Question:**
While designing a document ingestion pipeline, you need to decide the chunk size for embedding and retrieval. Which factor most strongly influences the optimal chunk size in practice?

A. Target LLM context window size alone
B. Distribution of semantic boundaries in source documents
C. Maximum allowable embedding dimensionality
D. Throughput limits of the vector database

**Answer:** ✅ **B. Distribution of semantic boundaries in source documents**

**Explanation:** Chunking should preserve meaningful context rather than follow arbitrary token limits.

---

## Q4. High Retrieval Recall but Low Answer Correctness

**Question:**
Offline evaluation shows high retrieval recall but low answer correctness. What is the most plausible root cause?

A. The retriever finds relevant documents, but the generator fails to use them effectively.
B. The embedding model dimensions are too high.
C. The vector database indexing strategy is incorrect.
D. The chunk overlap is too small.

**Answer:** ✅ **A. The retriever finds relevant documents, but the generator fails to use them effectively.**

**Explanation:** Relevant information is retrieved, but generation cannot synthesize or ground answers correctly.

---

-- %%
%python
## Q5. What is the output?

import pandas as pd

df = pd.DataFrame({
    'grp': ['X', 'X', 'Y'],
    'val': [10, 20, 30]
})

print(df.groupby('grp')['val'].apply(lambda x: x-x.mean()))

-- %%
## Q6. Knowledge Distillation in RAG

**Question:**
How can knowledge distillation be applied to improve RAG model training?

A. By training components in complete isolation from each other
B. By using only the better retrieval component without the generation model
C. By eliminating the need for any training data
D. By using a large teacher model to guide the training of a smaller, more efficient RAG student model

**Answer:** ✅ **D. Using a large teacher model to train a smaller student model**

**Explanation:** Distillation transfers knowledge from a powerful model into a compact one.

---

## Q7. PEFT and Quantization

**Question:**
How does PEFT compression interact with quantization techniques?

A. PEFT and quantization cannot be effectively combined together.
B. PEFT completely eliminates the need for quantization.
C. Quantization fully eliminates the need for PEFT.
D. PEFT can be combined with quantization for additional model compression.

**Answer:** ✅ **D. PEFT can be combined with quantization**

**Explanation:** Techniques like QLoRA successfully combine both approaches.

---

## Q8. Multi-Hop Reasoning

**Question:**
A RAG system struggles with queries requiring the combination of information across multiple documents. Which architectural enhancement is most effective for multi-hop reasoning?

A. Increasing the number of retrieved documents for every query
B. Introducing intermediate reasoning or retrieval steps
C. Using larger embedding models to enrich semantics
D. Switching to a purely generative model without retrieval

**Answer:** ✅ **B. Introducing intermediate reasoning or retrieval steps**

**Explanation:** Iterative retrieval enables evidence gathering across documents.

---

-- %%
%python
## Q9. What is the output of:
import pandas as pd
left = pd.DataFrame({'id':[1, 1, 2], 'x': [10, 20, 30]})
right = pd.DataFrame({'id':[1, 1, 3], 'y': [100, 200, 300]})
res = pd.merge(left, right, on='id', how = 'inner')
print(res.shape,"\n", res)

-- %%
## Q10. Accuracy in LLM Evaluation

**Question:**
What does accuracy measure in the context of LLM evaluation?

A. The percentage of correct responses or predictions made by the model
B. The speed of model inference only
C. The memory usage during model operation
D. The size of the training dataset

**Answer:** ✅ **A. Percentage of correct responses**

**Explanation:** Accuracy measures how often predictions match the ground truth.

---

## Q11. Reactive vs Deliberative Agents

**Question:**
What distinguishes a reactive agent from a deliberative agent in terms of decision-making?

A. Reactive agents respond immediately to stimuli, while deliberative agents use internal reasoning and planning.
B. Reactive agents use complex planning algorithms, while deliberative agents use simple rules.
C. Reactive agents require more computational resources than deliberative agents.
D. Reactive agents can only operate in virtual environments.

**Answer:** ✅ **A. Immediate response vs planning**

**Explanation:** Deliberative agents reason before acting, whereas reactive agents do not.

---

## Q12. Vector Search at Scale

**Question:**
When implementing a vector similarity search system for a RAG application with 1 million document embeddings, which technical challenge presents the most significant performance limitation?

A. Efficiency degradation in high-dimensional spaces affecting accuracy
B. Storage optimization trade-offs between index size and query throughput
C. Severe latency variation across heterogeneous collections
D. Representation drift requiring periodic re-indexing

**Answer:** ✅ **B. Storage optimization trade-offs between index size and query throughput**

**Explanation:** ANN systems balance retrieval speed, memory usage, and accuracy.

---

## Q13. Transformers and Long-Range Dependencies

**Question:**
Which of the following best explains why Transformers handle long-range dependencies better than vanilla RNNs?

A. Transformers directly model pairwise token interactions through attention instead of relying on sequential propagation.
B. Transformers use recurrence with larger hidden states.
C. Transformers remove the need for embeddings.
D. Transformers only work because of larger datasets.

**Answer:** ✅ **A. Self-attention**

**Explanation:** Attention allows direct access to distant tokens.

---

## Q14. Chain vs Agent

**Question:**
When deciding between a simple chain and an agent, which criterion is the strongest?

A. Use agents only for chatbots.
B. Use an agent whenever an LLM is present.
C. Use a simple chain for fixed, predictable workflows and an agent when dynamic tool selection and branching decisions are needed.
D. Chains cannot call tools.

**Answer:** ✅ **C. Fixed workflow vs dynamic decisions**

**Explanation:** Agents add value only when adaptability is required.

---

## Q15. Utility Theory in Agents

**Question:**
What role does utility theory play in goal-oriented agent behavior?

A. It eliminates the need for goal specification.
B. It provides a mathematical framework for comparing and prioritizing different outcomes.
C. It restricts agents to pursuing only single objectives.
D. It replaces all other decision-making mechanisms.

**Answer:** ✅ **B. Comparing outcomes**

**Explanation:** Utility functions help agents choose the most desirable action.

---

## Q16. Benefit of RAG in 2026

**Question:**
Compared with long-context windows, what is a primary benefit of RAG systems in 2026?

A. Higher reasoning accuracy on multi-hop questions using targeted retrieval
B. Lower query latency versus 30–60 second contexts
C. Ability to process 1 million tokens in a single prompt
D. Simplicity of implementation without a database

**Answer:** ✅ **A. Higher reasoning accuracy through targeted evidence**

**Explanation:** RAG grounds answers using relevant external information.

---

## Q17. Performance Evaluation in RAG

**Question:**
How does performance evaluation help in RAG?

A. It increases model speed.
B. It measures the accuracy of generated responses.
C. It only measures retrieval speed.
D. It focuses on model complexity.

**Answer:** ✅ **B. Measures response quality**

**Explanation:** Evaluation assesses whether generated answers are correct and useful.

---

## Q18. Multi-Agent Systems

**Question:**
Which architectural pattern is commonly used for multi-agent systems?

A. Distributed agent architecture
B. Client-server architecture only
C. Monolithic architecture
D. Peer-to-peer networking only

**Answer:** ✅ **A. Distributed agent architecture**

**Explanation:** Specialized agents collaborate while remaining loosely coupled.

---

## Q19. Improving Retrieval Consistency

**Question:**
In a RAG architecture, you observe that semantically similar queries often retrieve partially overlapping but inconsistent documents. Which modification is most likely to improve retrieval consistency without significantly increasing storage overhead?

A. Increase embedding dimensionality.
B. Introduce query rewriting using an LLM.
C. Store multiple embeddings for each document.
D. Replace cosine similarity with Euclidean distance.

**Answer:** ✅ **B. Introduce query rewriting using an LLM**

**Explanation:** Query rewriting normalizes user intent and improves retrieval consistency.

---

These are excellent **advanced interview-style GenAI and Agentic AI questions**, covering topics such as **hybrid retrieval, chunking strategies, RAG evaluation, PEFT, quantization, multi-hop reasoning, agents, utility theory, and large-scale vector search**.
